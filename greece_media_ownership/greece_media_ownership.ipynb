# %%
import pandas as pd

# Load the dataset
df_greece = pd.read_excel("Search_collection_id_10800_schema_LegalEntity.xlsx")

# Inspect the first few rows
print(df_greece.head())

# Check the columns
print(df_greece.columns)

# Basic info
print(df_greece.info())

# Number of rows
print(f"Number of legal entities: {len(df_greece)}")
# Out:
#                                                   ID  \
# 0  00d2328335d23fcdf9d1b9aa6484ecc6c78b738d.42332...
# 1  0104ab6679d47a1394fb1f40b353b8c12ac3bee5.28b0b...
# 2  0148ea9d2cfe368bf285069083c02e17faa18eb5.6572f...
# 3  018a20a31c326ec5c1adbf48721180d01118134b.9fabc...
# 4  018b96e90a71d4630a61a461e681db97261856f7.bcee5...
#
#                                                  url              collection  \
# 0  https://aleph.occrp.org/entities/00d2328335d23...  Greece Media Ownership
# 1  https://aleph.occrp.org/entities/0104ab6679d47...  Greece Media Ownership
# 2  https://aleph.occrp.org/entities/0148ea9d2cfe3...  Greece Media Ownership
# 3  https://aleph.occrp.org/entities/018a20a31c326...  Greece Media Ownership
# 4  https://aleph.occrp.org/entities/018b96e90a71d...  Greece Media Ownership
#
#                                                 Name  E-Mail  Phone  \
# 0                             ΔΡΟΥΖΑ ΑΝΝΑΔΡΟΥΖΑ ΑΝΝΑ     NaN    NaN
# 1                                  ΜΑΝΙΑΤΗΣ ΣΩΤΗΡΙΟΣ     NaN    NaN
# 2                                    ΜΗΣΙΑΚΟΥΛΗ ΛΗΤΩ     NaN    NaN
# 3  ONMEDIA DIGITAL ΜΟΝΟΠΡΟΣΩΠΗ ΑΝΩΝΥΜΗ ΕΤΑΙΡΕΙΑ; ...     NaN    NaN
# 4                                   ΠΩΠΟΤΑΣ ΓΕΩΡΓΙΟΣ     NaN    NaN
#
#    Registration number Country               Legal form  Status  ...  \
# 0                  NaN      gr                      NaN     NaN  ...
# 1                  NaN      gr                      NaN     NaN  ...
# 2                  NaN      gr                      NaN     NaN  ...
# 3                  NaN      gr  Ανώνυμη Εταιρεία (Α.Ε.)     NaN  ...
# 4                  NaN      gr                      NaN     NaN  ...
#
#                                          Source link  Summary   Tax Number  \
# 0  https://mt.media.gov.gr/submissions/public/MHT...      NaN          NaN
# 1  https://mt.media.gov.gr/submissions/public/MET...      NaN          NaN
# 2  https://mt.media.gov.gr/submissions/public/MET...      NaN          NaN
# 3  https://mt.media.gov.gr/submissions/public/MHT...      NaN  996846160.0
# 4  https://mt.media.gov.gr/submissions/public/MET...      NaN          NaN
#
#    Tax status  Topics  V.A.T. Identifier  Weak alias  \
# 0         NaN     NaN                NaN         NaN
# 1         NaN     NaN                NaN         NaN
# 2         NaN     NaN                NaN         NaN
# 3         NaN     NaN                NaN         NaN
# 4         NaN     NaN                NaN         NaN
#
#                                              Website  Wikidata ID  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3  https://www.cretalive.gr/; https://www.capitan...          NaN
# 4                                                NaN          NaN
#
#    Wikipedia Article
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 48 columns]
# Index(['ID', 'url', 'collection', 'Name', 'E-Mail', 'Phone',
#        'Registration number', 'Country', 'Legal form', 'Status', 'Address',
#        'Bureau van Dijk ID', 'Classification', 'Country of origin',
#        'Created at', 'D-U-N-S', 'Description', 'Dissolution date', 'ICIJ ID',
#        'ID Number', 'INN', 'Incorporation date', 'Jurisdiction', 'Keywords',
#        'LEI', 'Modified on', 'Notes', 'OGRN', 'OKPO', 'OpenCorporates URL',
#        'Other name', 'Previous name', 'Program', 'Publishing source',
#        'Publishing source URL', 'Retrieved on', 'SWIFT/BIC', 'Sector',
#        'Source link', 'Summary', 'Tax Number', 'Tax status', 'Topics',
#        'V.A.T. Identifier', 'Weak alias', 'Website', 'Wikidata ID',
#        'Wikipedia Article'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     2199 non-null   object
#  1   url                    2199 non-null   object
#  2   collection             2199 non-null   object
#  3   Name                   2199 non-null   object
#  4   E-Mail                 0 non-null      float64
#  5   Phone                  0 non-null      float64
#  6   Registration number    0 non-null      float64
#  7   Country                2199 non-null   object
#  8   Legal form             710 non-null    object
#  9   Status                 0 non-null      float64
#  10  Address                710 non-null    object
#  11  Bureau van Dijk ID     0 non-null      float64
#  12  Classification         0 non-null      float64
#  13  Country of origin      0 non-null      float64
#  14  Created at             0 non-null      float64
#  15  D-U-N-S                0 non-null      float64
#  16  Description            0 non-null      float64
#  17  Dissolution date       0 non-null      float64
#  18  ICIJ ID                0 non-null      float64
#  19  ID Number              0 non-null      float64
#  20  INN                    0 non-null      float64
#  21  Incorporation date     0 non-null      float64
#  22  Jurisdiction           0 non-null      float64
#  23  Keywords               710 non-null    object
#  24  LEI                    0 non-null      float64
#  25  Modified on            0 non-null      float64
#  26  Notes                  0 non-null      float64
#  27  OGRN                   0 non-null      float64
#  28  OKPO                   0 non-null      float64
#  29  OpenCorporates URL     0 non-null      float64
#  30  Other name             0 non-null      float64
#  31  Previous name          0 non-null      float64
#  32  Program                0 non-null      float64
#  33  Publishing source      0 non-null      float64
#  34  Publishing source URL  0 non-null      float64
#  35  Retrieved on           0 non-null      float64
#  36  SWIFT/BIC              0 non-null      float64
#  37  Sector                 0 non-null      float64
#  38  Source link            2199 non-null   object
#  39  Summary                0 non-null      float64
#  40  Tax Number             710 non-null    float64
#  41  Tax status             0 non-null      float64
#  42  Topics                 0 non-null      float64
#  43  V.A.T. Identifier      0 non-null      float64
#  44  Weak alias             0 non-null      float64
#  45  Website                574 non-null    object
#  46  Wikidata ID            0 non-null      float64
#  47  Wikipedia Article      0 non-null      float64
# dtypes: float64(38), object(10)
# memory usage: 824.8+ KB
# None
# Number of legal entities: 2199

# %%
import pandas as pd
from tqdm import tqdm
import googlemaps

# Load dataset
df = pd.read_excel("Search_collection_id_10800_schema_LegalEntity.xlsx")

# Keep only rows with addresses
df_geo = df[df['Address'].notna()].copy()
print(f"Number of entities with addresses: {len(df_geo)}")

# Initialize Google Maps client
gmaps = googlemaps.Client(key=open("google_api_key.txt").read().strip())

# Add columns for Latitude and Longitude
df_geo['Latitude'] = None
df_geo['Longitude'] = None

# Geocode each address with a progress bar
for i, row in tqdm(df_geo.iterrows(), total=len(df_geo)):
    try:
        geocode_result = gmaps.geocode(row['Address'] + ", Greece")
        if geocode_result:
            loc = geocode_result[0]['geometry']['location']
            df_geo.at[i, 'Latitude'] = loc['lat']
            df_geo.at[i, 'Longitude'] = loc['lng']
    except Exception as e:
        print(f"Error geocoding {row['Address']}: {e}")

# Save geocoded data
df_geo.to_csv("Greece_MediaOwnership_geocoded.csv", index=False)
print("Geocoding complete and saved!")
# Out:
# Number of entities with addresses: 710
# 00%|██████████████████████████████████████████████████████████████████| 710/710 [01:54<00:00,  6.20it/s]
# Geocoding complete and saved!

# %%
df_geo.head()
# Out:
#                                                    ID  \
# 3   018a20a31c326ec5c1adbf48721180d01118134b.9fabc...
# 11  04ba3c267a165717235088635e7694aea1e686b6.2af84...
# 13  079c06fd532f0e25df3ce41d4a866b34e25190df.d6b2c...
# 14  088bb5ae028948a1c6afaca27047652c8f7f5ff1.314bd...
# 16  09974ba661794cdbf96181566703460fe71609aa.579d4...
#
#                                                   url              collection  \
# 3   https://aleph.occrp.org/entities/018a20a31c326...  Greece Media Ownership
# 11  https://aleph.occrp.org/entities/04ba3c267a165...  Greece Media Ownership
# 13  https://aleph.occrp.org/entities/079c06fd532f0...  Greece Media Ownership
# 14  https://aleph.occrp.org/entities/088bb5ae02894...  Greece Media Ownership
# 16  https://aleph.occrp.org/entities/09974ba661794...  Greece Media Ownership
#
#                                                  Name  E-Mail  Phone  \
# 3   ONMEDIA DIGITAL ΜΟΝΟΠΡΟΣΩΠΗ ΑΝΩΝΥΜΗ ΕΤΑΙΡΕΙΑ; ...     NaN    NaN
# 11  ΥΙΟΙ ΣΑΒΒΑ ΤΣΟΠΑΝΑΚΗ Η ΚΩΤΙΑΔΗ ΟΕ; ΡΟΔΙΑΚΗ; ΕΦ...     NaN    NaN
# 13  TELIA INTERNET ΙΔΙΩΤΙΚΗ ΚΕΦΑΛΑΙΟΥΧΙΚΗ ΕΤΑΙΡΙΑ;...     NaN    NaN
# 14            THESSDIGITAL Ι Κ Ε; -; ΤΗESSDIGITAL IKE     NaN    NaN
# 16                                  ΧΑΛΟΣ ΓΕΩΡΓΙΟΣ; -     NaN    NaN
#
#     Registration number Country                                Legal form  \
# 3                   NaN      gr                   Ανώνυμη Εταιρεία (Α.Ε.)
# 11                  NaN      gr                 Ομόρρυθμη Εταιρεία (Ο.Ε.)
# 13                  NaN      gr  Ιδιωτική Κεφαλαιουχική Εταιρεία (Ι.Κ.Ε.)
# 14                  NaN      gr  Ιδιωτική Κεφαλαιουχική Εταιρεία (Ι.Κ.Ε.)
# 16                  NaN      gr                                   Ατομική
#
#     Status  ...   Tax Number  Tax status  Topics  V.A.T. Identifier  \
# 3      NaN  ...  996846160.0         NaN     NaN                NaN
# 11     NaN  ...   82924230.0         NaN     NaN                NaN
# 13     NaN  ...  801707355.0         NaN     NaN                NaN
# 14     NaN  ...  801907469.0         NaN     NaN                NaN
# 16     NaN  ...  170317325.0         NaN     NaN                NaN
#
#     Weak alias                                            Website  \
# 3          NaN  https://www.cretalive.gr/; https://www.capitan...
# 11         NaN                             http://WWW.RODIAKI.GR/
# 13         NaN                                http://pagenews.gr/
# 14         NaN                              http://theopinion.gr/
# 16         NaN                            http://oichalialive.gr/
#
#     Wikidata ID  Wikipedia Article   Latitude  Longitude
# 3           NaN                NaN  35.329239  25.138288
# 11          NaN                NaN  36.439675  28.234484
# 13          NaN                NaN  38.040843  23.803142
# 14          NaN                NaN  40.635464  22.944377
# 16          NaN                NaN   39.60419  21.981511
#
# [5 rows x 50 columns]

# %%
import gmplot

# Drop rows without successful coordinates
df_map = df_geo.dropna(subset=['Latitude', 'Longitude'])

# Center map on Greece
lat_center = df_map['Latitude'].mean()
lng_center = df_map['Longitude'].mean()

gmap = gmplot.GoogleMapPlotter(lat_center, lng_center, 6, apikey=open("google_api_key.txt").read().strip())

# Add markers
for idx, row in df_map.iterrows():
    gmap.marker(row['Latitude'], row['Longitude'], title=row['Name'].replace('"', '\\"'))

# Save HTML
gmap.draw("Greece_MediaOwnership_map.html")
print("Saved interactive map!")
# Out:
# Saved interactive map!
