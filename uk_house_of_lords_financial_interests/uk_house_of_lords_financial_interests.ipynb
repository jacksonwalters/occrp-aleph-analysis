# %%
import pandas as pd

files = [
    "Search_collection_id_9284_schema_Company.xlsx",
    "Search_collection_id_9284_schema_Person.xlsx",
    "Search_collection_id_9284_schema_Event.xlsx",
    "Search_collection_id_9284_schema_RealEstate.xlsx"
]

for f in files:
    df = pd.read_excel(f)
    print(f"File: {f}")
    print(f"Number of rows: {len(df)}")
    print(f"Columns: {list(df.columns)}")
    print(df.head(20))
    print("\n" + "-"*80 + "\n")
# Out:
# File: Search_collection_id_9284_schema_Company.xlsx
# Number of rows: 4700
# ...
