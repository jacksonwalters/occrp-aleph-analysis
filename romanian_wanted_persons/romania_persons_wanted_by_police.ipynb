# %%
import pandas as pd

df_person = pd.read_excel("Search_collection_id_9327_schema_Person.xlsx")
df_address = pd.read_excel("Search_collection_id_9327_schema_Address.xlsx")

print("Person columns:", df_person.columns.tolist())
print("Address columns:", df_address.columns.tolist())

print("\nSample Person rows:")
print(df_person.head())

print("\nSample Address rows:")
print(df_address.head())
# Out:
# Person columns: ['ID', 'url', 'collection', 'Name', 'E-Mail', 'Last name', 'Phone', 'Birth date', 'Nationality', 'Address', 'Bureau van Dijk ID', 'Classification', 'Country', 'Country of birth', 'Country of origin', 'Created at', 'D-U-N-S', 'Death date', 'Description', 'Dissolution date', 'Education', 'Ethnicity', 'First name', 'Gender', 'ICIJ ID', 'ID Number', 'INN', 'Incorporation date', 'Jurisdiction', 'Keywords', 'LEI', 'Legal form', 'Matronymic', 'Middle name', 'Modified on', 'Name suffix', 'Notes', 'OGRN', 'OKPO', 'OpenCorporates URL', 'Other name', 'Passport number', 'Patronymic', 'Place of birth', 'Political association', 'Position', 'Previous name', 'Program', 'Publishing source', 'Publishing source URL', 'Registration number', 'Religion', 'Retrieved on', 'SWIFT/BIC', 'Second name', 'Sector', 'Source link', 'Status', 'Summary', 'Tax Number', 'Tax status', 'Title', 'Topics', 'V.A.T. Identifier', 'Weak alias', 'Website', 'Wikidata ID', 'Wikipedia Article']
# Address columns: ['ID', 'url', 'collection', 'City', 'Full address', 'Remarks', 'Summary', 'Country', 'Street address', 'Address', 'Created at', 'Description', 'Google Places ID', 'Keywords', 'Latitude', 'Longitude', 'Modified on', 'Name', 'Notes', 'OpenStreetmap Place ID', 'Other name', 'PO Box', 'Postal code', 'Previous name', 'Program', 'Publishing source', 'Publishing source URL', 'Region', 'Retrieved on', 'Source link', 'State', 'Street address (ctd.)', 'Topics', 'Weak alias', 'Wikidata ID', 'Wikipedia Article']
#
# Sample Person rows:
#                                                   ID  \
# 0  89d76b94f41b84566ef6d8bd04ac0f35880a4623.c6911...
# 1  8ad106dcb7087ba60910a3b74da6618cf6bb9c39.6d653...
# 2  8cfeadcdfeb2e9eac13ef34200cf2928f2dc9e87.376c3...
# 3  8da0fa72e39ef5e28df01dfc97aa603e80152025.46388...
# 4  8dbc045c1178c56a1c31bd9aa019c3939bfc8580.e5551...
#
#                                                  url  \
# 0  https://aleph.occrp.org/entities/89d76b94f41b8...
# 1  https://aleph.occrp.org/entities/8ad106dcb7087...
# 2  https://aleph.occrp.org/entities/8cfeadcdfeb2e...
# 3  https://aleph.occrp.org/entities/8da0fa72e39ef...
# 4  https://aleph.occrp.org/entities/8dbc045c1178c...
#
#                               collection                        Name  E-Mail  \
# 0  Romania — People wanted by the police       BAJKO GYORGY SZABOLCS     NaN
# 1  Romania — People wanted by the police  KASHAN SALHLADIN ABDUSALAM     NaN
# 2  Romania — People wanted by the police                  RAPAS IOAN     NaN
# 3  Romania — People wanted by the police                  BANTA IOAN     NaN
# 4  Romania — People wanted by the police   FRATILA CRISTINEL CIPRIAN     NaN
#
#    Last name  Phone  Birth date Nationality                          Address  \
# 0        NaN    NaN         NaN         NaN                              NaN
# 1        NaN    NaN  1990-10-01          iq                             IRAK
# 2        NaN    NaN  1959-05-04          ro  Cluj-Napoca, jud. CLUJ, ROMANIA
# 3        NaN    NaN         NaN         NaN                              NaN
# 4        NaN    NaN  1977-09-12          ro   Focsani, jud. VRANCEA, ROMANIA
#
#    ...                                            Summary  Tax Number  \
# 0  ...                                    Reason: . Deed:         NaN
# 1  ...  Reason: mandat de executare a pedepsei cu inch...         NaN
# 2  ...  Reason: mandat de executare a pedepsei cu inch...         NaN
# 3  ...                                    Reason: . Deed:         NaN
# 4  ...  Reason: mandat de executare a pedepsei cu inch...         NaN
#
#   Tax status  Title  Topics  V.A.T. Identifier  Weak alias  Website  \
# 0        NaN    NaN   crime                NaN         NaN      NaN
# 1        NaN    NaN   crime                NaN         NaN      NaN
# 2        NaN    NaN   crime                NaN         NaN      NaN
# 3        NaN    NaN   crime                NaN         NaN      NaN
# 4        NaN    NaN   crime                NaN         NaN      NaN
#
#   Wikidata ID  Wikipedia Article
# 0         NaN                NaN
# 1         NaN                NaN
# 2         NaN                NaN
# 3         NaN                NaN
# 4         NaN                NaN
#
# [5 rows x 68 columns]
#
# Sample Address rows:
#                                                   ID  \
# 0  007f8a5520f42c873c0376a1b6fad6d8ee8cb164.b6b78...
# 1  2078ecdb39eefad28984fdcce88d8b0e68a4da40.ddba2...
# 2  26ca7212ab5bc23c2cdd5cb745d6ed4aafbb0b19.dbf9d...
# 3  2f9062908abeee33bd2538cd620cd7a5e2203f45.2c474...
# 4  2fb87dd9d54dca0cd93821fb0450caecdfa9a2b8.63884...
#
#                                                  url  \
# 0  https://aleph.occrp.org/entities/007f8a5520f42...
# 1  https://aleph.occrp.org/entities/2078ecdb39eef...
# 2  https://aleph.occrp.org/entities/26ca7212ab5bc...
# 3  https://aleph.occrp.org/entities/2f9062908abee...
# 4  https://aleph.occrp.org/entities/2fb87dd9d54dc...
#
#                               collection  City  \
# 0  Romania — People wanted by the police   NaN
# 1  Romania — People wanted by the police   NaN
# 2  Romania — People wanted by the police   NaN
# 3  Romania — People wanted by the police   NaN
# 4  Romania — People wanted by the police   NaN
#
#                       Full address  Remarks  Summary  Country  Street address  \
# 0  Pacureti, jud. PRAHOVA, ROMANIA      NaN      NaN      NaN             NaN
# 1     Adunati, jud. ARGES, ROMANIA      NaN      NaN      NaN             NaN
# 2      Niuved, jud. BIHOR, ROMANIA      NaN      NaN      NaN             NaN
# 3  Bunea Mare, jud. TIMIS, ROMANIA      NaN      NaN      NaN             NaN
# 4      Uiasca, jud. ARGES, ROMANIA      NaN      NaN      NaN             NaN
#
#    Address  ...  Publishing source URL  Region  Retrieved on  Source link  \
# 0      NaN  ...                    NaN     NaN           NaN          NaN
# 1      NaN  ...                    NaN     NaN           NaN          NaN
# 2      NaN  ...                    NaN     NaN           NaN          NaN
# 3      NaN  ...                    NaN     NaN           NaN          NaN
# 4      NaN  ...                    NaN     NaN           NaN          NaN
#
#    State  Street address (ctd.)  Topics  Weak alias  Wikidata ID  \
# 0    NaN                    NaN     NaN         NaN          NaN
# 1    NaN                    NaN     NaN         NaN          NaN
# 2    NaN                    NaN     NaN         NaN          NaN
# 3    NaN                    NaN     NaN         NaN          NaN
# 4    NaN                    NaN     NaN         NaN          NaN
#
#    Wikipedia Article
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 36 columns]

# %%
# Number of rows
print("People:", len(df_person))
print("Addresses:", len(df_address))

# Sample addresses from both
print("\nPerson address samples:")
print(df_person['Address'].dropna().head(10))

print("\nAddress full address samples:")
print(df_address['Full address'].dropna().head(10))

# Try fuzzy matching overlap
person_addresses = set(df_person['Address'].dropna().unique())
full_addresses = set(df_address['Full address'].dropna().unique())

matches = person_addresses.intersection(full_addresses)
print(f"\nExact matches found: {len(matches)}")
print(list(matches)[:20])
# Out:
# People: 4472
# Addresses: 1332
#
# Person address samples:
# 1                                               IRAK
# 2                    Cluj-Napoca, jud. CLUJ, ROMANIA
# 4                     Focsani, jud. VRANCEA, ROMANIA
# 5                   Jilavele, jud. IALOMITA, ROMANIA
# 6                  Aiudul de Sus, jud. ALBA, ROMANIA
# 7                  Piatra Neamt, jud. NEAMT, ROMANIA
# 8                 Baia Mare, jud. MARAMURES, ROMANIA
# 9                  Beica de Jos, jud. MURES, ROMANIA
# 10                      Braila, jud. BRAILA, ROMANIA
# 11    Drobeta-Turnu Severin, jud. MEHEDINTI, ROMANIA
# Name: Address, dtype: object
#
# Address full address samples:
# 0            Pacureti, jud. PRAHOVA, ROMANIA
# 1               Adunati, jud. ARGES, ROMANIA
# 2                Niuved, jud. BIHOR, ROMANIA
# 3            Bunea Mare, jud. TIMIS, ROMANIA
# 4                Uiasca, jud. ARGES, ROMANIA
# 5             Sacel, jud. MARAMURES, ROMANIA
# 6           Urechesti, jud. VRANCEA, ROMANIA
# 7             Nejlovelu, jud. ARGES, ROMANIA
# 8    Stefanestii de Jos, jud. ILFOV, ROMANIA
# 9             Catauti, jud. VRANCEA, ROMANIA
# Name: Full address, dtype: object
#
# Exact matches found: 1188
# ['Petrachioaia, jud. ILFOV, ROMANIA', 'Cristian, jud. SIBIU, ROMANIA', 'Girbovat, jud. CARAS-SEVERIN, ROMANIA', 'Cefa, jud. BIHOR, ROMANIA', 'Fiscut, jud. ARAD, ROMANIA', 'Pingaracior, jud. NEAMT, ROMANIA', 'Ploscuteni, jud. VRANCEA, ROMANIA', 'Botorogi, jud. GORJ, ROMANIA', 'Sincraiu de Mures, jud. MURES, ROMANIA', 'Bistrita, jud. BISTRITA-NASAUD, ROMANIA', 'Padureni, jud. VRANCEA, ROMANIA', 'Buhusi, jud. BACAU, ROMANIA', 'Nimigea de Jos, jud. BISTRITA-NASAUD, ROMANIA', 'Comanesti, jud. HARGHITA, ROMANIA', 'Ditesti, jud. PRAHOVA, ROMANIA', 'Vadu Moldovei, jud. SUCEAVA, ROMANIA', 'Rachitosu, jud. VRANCEA, ROMANIA', 'Gradistea, jud. GIURGIU, ROMANIA', 'Halchiu, jud. BRASOV, ROMANIA', 'MAROC']

# %%
import pandas as pd

# Load
df_person = pd.read_excel("Search_collection_id_9327_schema_Person.xlsx")
df_address = pd.read_excel("Search_collection_id_9327_schema_Address.xlsx")

# Drop NaNs so we don’t join on empty strings
df_person = df_person.dropna(subset=["Address"])
df_address = df_address.dropna(subset=["Full address"])

# Merge on the shared address text
df_merged = df_person.merge(
    df_address,
    left_on="Address",
    right_on="Full address",
    suffixes=("_person", "_addr")
)

print(f"Merged dataset has {len(df_merged)} rows")

# Check merged sample
print(df_merged[["Name_person", "Address_person", "Latitude", "Longitude"]].head())
# Out:
# Merged dataset has 3564 rows
#                   Name_person                     Address_person  Latitude  \
# 0  KASHAN SALHLADIN ABDUSALAM                               IRAK       NaN
# 1                  RAPAS IOAN    Cluj-Napoca, jud. CLUJ, ROMANIA       NaN
# 2   FRATILA CRISTINEL CIPRIAN     Focsani, jud. VRANCEA, ROMANIA       NaN
# 3      STANCIU NEDEA PETRISOR   Jilavele, jud. IALOMITA, ROMANIA       NaN
# 4               DRAGOI STEFAN  Aiudul de Sus, jud. ALBA, ROMANIA       NaN
#
#    Longitude
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
print("Unique person addresses:", df_person["Address"].nunique())
print("Unique address full addresses:", df_address["Full address"].nunique())
print("Unique matches:", df_person["Address"].isin(df_address["Full address"]).sum())
# Out:
# Unique person addresses: 1189
# Unique address full addresses: 1332
# Unique matches: 3564

# %%
# Check how many people per address
df_counts = df_merged.groupby("Full address")["ID_person"].nunique().reset_index()
df_counts = df_counts.sort_values("ID_person", ascending=False)

print(df_counts.head(10))
# Out:
#                         Full address  ID_person
# 912     Sector 3, BUCURESTI, ROMANIA        209
# 911     Sector 2, BUCURESTI, ROMANIA        131
# 914     Sector 5, BUCURESTI, ROMANIA        130
# 910     Sector 1, BUCURESTI, ROMANIA         84
# 913     Sector 4, BUCURESTI, ROMANIA         74
# 1052  Timisoara, jud. TIMIS, ROMANIA         73
# 915     Sector 6, BUCURESTI, ROMANIA         70
# 501         Iasi, jud. IASI, ROMANIA         65
# 145     Brasov, jud. BRASOV, ROMANIA         61
# 142     Braila, jud. BRAILA, ROMANIA         52
